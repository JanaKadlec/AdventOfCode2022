# %% [markdown]
# --- Day 3: Rucksack Reorganization ---
#
# One Elf has the important job of loading all of the rucksacks with supplies for the jungle journey. Unfortunately, that Elf didn't quite follow the packing instructions, and so a few items now need to be rearranged.
#
# Each rucksack has two large compartments. All items of a given type are meant to go into exactly one of the two compartments. The Elf that did the packing failed to follow this rule for exactly one item type per rucksack.
#
# The Elves have made a list of all of the items currently in each rucksack (your puzzle input), but they need your help finding the errors. Every item type is identified by a single lowercase or uppercase letter (that is, a and A refer to different types of items).
#
# The list of items for each rucksack is given as characters all on a single line. A given rucksack always has the same number of items in each of its two compartments, so the first half of the characters represent items in the first compartment, while the second half of the characters represent items in the second compartment.
#
# For example, suppose you have the following list of contents from six rucksacks:
#
# vJrwpWtwJgWrhcsFMMfFFhFp
#
# jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
#
# PmmdzqPrVvPwwTWBwg
#
# wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
#
# ttgJtRGJQctTZtZT
#
# CrZsJsPPZsGzwwsLwLmpwMDw
#
# The first rucksack contains the items vJrwpWtwJgWrhcsFMMfFFhFp, which means its first compartment contains the items vJrwpWtwJgWr, while the second compartment contains the items hcsFMMfFFhFp. The only item type that appears in both compartments is lowercase p.
#
# The second rucksack's compartments contain jqHRNqRjqzjGDLGL and rsFMfFZSrLrFZsSL. The only item type that appears in both compartments is uppercase L.
#
# The third rucksack's compartments contain PmmdzqPrV and vPwwTWBwg; the only common item type is uppercase P.
#
# The fourth rucksack's compartments only share item type v.
#
#
# The fifth rucksack's compartments only share item type t.
#
# The sixth rucksack's compartments only share item type s.
#
# To help prioritize item rearrangement, every item type can be converted to a priority:
#
# Lowercase item types a through z have priorities 1 through 26.
# Uppercase item types A through Z have priorities 27 through 52.
# In the above example, the priority of the item type that appears in both compartments of each rucksack is 16 (p), 38 (L), 42 (P), 22 (v), 20 (t), and 19 (s); the sum of these is 157.
#
# Find the item type that appears in both compartments of each rucksack. What is the sum of the priorities of those item types?

# %%
import numpy as np

with open('C:\\Users\\janak\\Documents\\08_PythonGit\\AdventOfCode2022\\Vstupy\\AOC_202203.txt', encoding='utf-8') as vstup:
    radky = vstup.readlines()

radky=[cast.strip('\n') for cast in radky]

dupli = []
for radek in radky:
    delka = int(len(radek))
    pulka= int(delka/2)
    leva = radek[0:pulka]
    print(leva)
    prava= radek[pulka:]
    print(prava)
    inter = [pismeno for pismeno in leva if pismeno in prava]
    print(inter)
    x = np.array(inter)
    inter_uni = np.unique(x)
    print(inter_uni)
    dupli.append(inter_uni) 

print(dupli)
# Out:
# sfDRhjhHsHhgW
# PJvPmmQnmPqnW
# ['W']
# ['W']
# pTddGVwcpMTTCd
# nQJqqQqqqVtVms
# ['V']
# ['V']
# MdZCZGdcrC
# NRFZRhFssL
# ['Z', 'Z']
# ['Z']
# CttWnSnNfSnCHsW
# rTlTPPpPCTRrLpl
# ['C', 'C']
# ['C']
# DgqqghjqJBVgDM
# TPGVlRGwbfLLGP
# ['V']
# ['V']
# cgqBBhjqcBdM
# cWQcQNnNzsfv
# ['c', 'c']
# ['c']
# lnDWMgTLlTFlHHgDDgngWFnl
# BWNcBQrdjcrrdQrPBrdjhWhj
# ['W', 'W']
# ['W']
# JqSVRRVmmRqJJbZGGJqJvbm
# BNcjPNQNssQPhSSdwPwwwQr
# ['S']
# ['S']
# bCRJqGJJmzmJZRCm
# FNTLTttTzfFfLglf
# ['z']
# ['z']
# SPWvWMvCSPc
# jzjDbcwfjTl
# ['c']
# ['c']
# lLNRNLqhhQVQJlR
# jrjrDwTzzqzzfrb
# ['q']
# ['q']
# GRnRVhRJLFnnhtJQNVdLdL
# gWCmmZlMlgSCSWSgpZtPBM
# ['t']
# ['t']
# pTGFrLFTFWFpr
# LDBmLbSbtmBDb
# ['L']
# ['L']
# MqjwqJwZlqJjHlqjHHP
# mSbsffDmsStDnHnQmsm
# ['H', 'H', 'H']
# ['H']
# ZPJjVPZbVMRRPZwMJZVMNJM
# cGWpWFcWFFNFGrWTzWzFrzG
# ['N']
# ['N']
# MffZZtMTnTtSZLdfgSMt
# CHSbmWsGwbHGSqvmCqWb
# ['S', 'S']
# ['S']
# lzpQhrhphhlzDDhRP
# mBvqHGRbBbwbbssCB
# ['R']
# ['R']
# JJljpvhFrrjhp
# tnddMJfdtgnMT
# ['J', 'J']
# ['J']
# drCtpNLCLpTpJSd
# swQhvDbHZHDLDHQ
# ['L', 'L']
# ['L']
# WmWgBWRcRzVVWVBgBBnnlfgW
# HjmvjQhwbbbshQvZDQQjsHZC
# ['m']
# ['m']
# fqBzggWPPzBWBzffcfn
# MJdtFtrpqrGMpdCCTdM
# ['q']
# ['q']
# JwJWqNBNNdzzBSzGsqbdNJb
# VMpptPmZMrVZrrZMtPmPwDp
# ['w']
# ['w']
# THgfgffffHRhQR
# LVMGVQmGtLDGmM
# ['Q']
# ['Q']
# TjGchhlHhGfhRHgRg
# WJSqzJWWlqNSzsWSJ
# ['l']
# ['l']
# dNmPlzdvd
# spsFWwQmG
# ['m']
# ['m']
# bhZSbVJBJnLNTn
# wWVHMGwQsGMFFw
# ['V']
# ['V']
# RnnbbTnSnSSTTnLfR
# CCPqDPDNDlfCfDDcr
# ['f']
# ['f']
# lhhTcnPchPP
# HCCStwWTHbS
# ['T']
# ['T']
# GDRFNqlQJsGJqGJDqVNsqssD
# QBSZWHQBCZHHwbZbtHtwCbZW
# ['Q']
# ['Q']
# RNJrFJFJDrmqsVjNmD
# vrvfzfffcvdpMrvlfh
# ['r', 'r']
# ['r']
# DtLdNGHNfwBJQw
# gCrncgpSpcnlfC
# ['f']
# ['f']
# sGqWPMPTvPPhTjjsqRqPv
# SlzFFpjnnSrjczprgllFF
# ['j', 'j']
# ['j']
# vVPGPGMbPGqTRWsMqZhqvb
# ZNLLmLQddQdmBtBwBNBwNB
# ['Z']
# ['Z']
# ChVzhwpdpq
# HhtNmHHNHt
# ['h', 'h']
# ['h']
# QsjGTQcTWQjfjbssQ
# DPmHgfrrVrPZnntZD
# ['f']
# ['f']
# jTGJSGvWJ
# wqlvlCBqV
# ['v']
# ['v']
# pRVcSRffTPfBWfNVfWBW
# dJdwhvvwGjjFmGvhLTdh
# ['T']
# ['T']
# qsrHqtbDZqsnsZqCQDtHnQQ
# LwFvJFhGJwddvwLcCwJJJdv
# ['C']
# ['C']
# sgcqHnzqqzgnHnqrstZzqsn
# SPllRlVVSNpWVNVRgMBlVPW
# ['g', 'g']
# ['g']
# WRQTtHrTrrDRvQDHrbtJ
# lpdhLdGsDllfspLpphhs
# ['D', 'D']
# ['D']
# GzCSqCSmSmV
# SpsljphlpsL
# ['S', 'S', 'S']
# ['S']
# gVwCVGzmNmCN
# RQTvJQJHnvwQ
# ['w']
# ['w']
# psBDsswNjBc
# qtHtsTHsqtM
# ['s', 's', 's']
# ['s']
# vQrPqZPmvgQZrfgmPrfJQ
# lLvnLzVHLnSnnTLTnnHMt
# ['v', 'v']
# ['v']
# PRCJRPgmqrmZmmqQQ
# DDRwwNwjwDwpFjDDW
# ['R', 'R']
# ['R']
# VtBgCqbVjPbSbHtP
# RdrssZMFZlrRsBRw
# ['B']
# ['B']
# LzWmhcDqTDvnDWT
# FMrwRvwFrGZdGlZ
# ['v']
# ['v']
# zJLczJDnWDpDNzmDczWLzWzW
# NCbbttHPCHbSVbqgHSCjffQf
# ['N']
# ['N']
# TjTfvJjjvcjTQcDzMDfQT
# LLbLgVVVhMrWWblghbbLN
# ['M']
# ['M']
# dZHFSpqpq
# pbWrhhlWh
# ['p', 'p']
# ['p']
# dFwPBHqFSqwZSmZmSlqZ
# jTvvJTmzcJsTTTjfvsfQ
# ['m', 'm']
# ['m']
# qqqNTlfjzbMGJlHM
# SZtZzZgRZDgZDzdS
# ['z']
# ['z']
# nLCCVVcm
# gCdZdSlg
# ['C', 'C']
# ['C']
# cmQscBVpFsppsV
# lffQGJHjlWHJGq
# ['Q']
# ['Q']
# whwVGGZhVLwhsFF
# DCTrDccCctrcctL
# ['L']
# ['L']
# CzSSvPSz
# TBStSWND
# ['S', 'S', 'S']
# ['S']
# HllCHvHJPPqjCPvbfdvvb
# smhdRRRsmZhsRdMFQMRFQ
# ['d']
# ['d']
# gFCfCVfCsLCftsBsD
# bSHrbJRJJtrmrddrd
# ['t']
# ['t']
# hqQpqWhlNlpMlpp
# fdTRhmbmTdbdHJH
# ['h', 'h']
# ['h']
# NGvvjvpvpf
# GgGGDCZZBg
# ['G']
# ['G']
# rmBtgdddtqmmrqBGbLGJlmct
# WWvbNzvfpsVVfzzSVSTsWNpz
# ['b']
# ['b']
# RPDRjMhDF
# ljvsvzlSs
# ['j']
# ['j']
# wDChhnCQwD
# wmgJclqrgm
# ['w', 'w']
# ['w']
# WHrrDbWHQPzNrrRVMQJMQ
# GvvsvvjnDLvfsjsvwfGws
# ['D']
# ['D']
# dhdhZhcphZZZmtFFTcZSmcZ
# snfqjLRnngnpwnGfqfvvnRs
# ['p']
# ['p']
# FZcZhtmhFCttldFlSSmlSth
# QJzNVMbRPWWPJzrbbJCNMPH
# ['C']
# ['C']
# wMFBpvTppLpw
# fNfjggmNmGTj
# ['T']
# ['T']
# ddSDDbGHnRDQDZRHSZSdRZDQ
# zjjrzNNNfnmNrllhgglhfgWg
# ['n']
# ['n']
# bCQqsJqGDZCHb
# ppwvtVMMvJcLL
# ['J']
# ['J']
# pSpSVdLDFCvDDvCFv
# JgwjsJbNtmtJgSjmj
# ['S', 'S']
# ['S']
# ZcWNNBQf
# wjsttsbc
# ['c']
# ['c']
# WNQMBflQQNGQr
# FpFVVRDHpCMDR
# ['M']
# ['M']
# PfPvqLphWpWLtZSWpWL
# PjwJbmDwJbbDbmJVjPQ
# ['P', 'P']
# ['P']
# lQQnRGMll
# MjswrmwJM
# ['M']
# ['M']
# ggRGFFGGdlGGzFFzzFFcNB
# vSfLQZShZTtdLWWZWSWZSp
# ['d']
# ['d']
# lCfgHsVHJD
# dswNRmsMRQ
# ['s']
# ['s']
# vccvvFVrPc
# vQNRdnmqdR
# ['v', 'v', 'v']
# ['v']
# rctPBrPBTTpPFBLZZc
# CCgVHJHVjjbLHfCjfS
# ['L']
# ['L']
# dfGdsGGrlFFlbWjfgblh
# JhLDLDDMLNvJNLLBnmLB
# ['h']
# ['h']
# tSppwQQHSSVtwStSpZZVqR
# JmBDzLvwPmzJznBDDmLBBJ
# ['w', 'w']
# ['w']
# cHvtpRSvptCR
# bbjrrcfjrWjf
# ['c']
# ['c']
# BBdHdjgQdjMMsHJs
# cFnrzLpLgznLFzcF
# ['g']
# ['g']
# wvllmNmVvZfvmZWqc
# PptPztFSWLFGrrFnt
# ['W']
# ['W']
# ZbCvqqmNvflfVTbZfNll
# sjHdjdhhHDTHRBJjjMsc
# ['T']
# ['T']
# FNCPtPtgLFJwPwflFwSrLF
# cMczQZTbMVmzzVZMcNVVVb
# ['N']
# ['N']
# DhRDdhpW
# QDZmzVSQ
# ['D', 'D']
# ['D']
# vnhBSHppjRBHqpW
# vrPFtJLJlLvfLPF
# ['v']
# ['v']
# nmcSnnWjmf
# CTcHPHJCvh
# ['c']
# ['c']
# zdDdlrrzGF
# FLPtPhBBhH
# ['F']
# ['F']
# NGNGrzrRrzphwwwM
# mqqfnsfZZNbSjQSN
# ['N', 'N']
# ['N']
# lgznQGWQLQWlnSzHSQlwnl
# DhCbZhZhZChPChwDcDphcb
# ['w']
# ['w']
# jTRvVVrMvmL
# CPNcNZhRNcD
# ['R']
# ['R']
# jfftvsrVJLsVvJqsmfqjfj
# lQgzlQWFzHFGGBQgtFgnnH
# ['t']
# ['t']
# sllpwssrsCwr
# TRgCHGCTcnZD
# ['C']
# ['C']
# jjzJtSdhdzbJWhdQqLdzqS
# HmDZBGZmmcGGgBGTDRBQTD
# ['Q']
# ['Q']
# SVjgVhgtbVzJ
# PfFpvvNrNswV
# ['V', 'V', 'V']
# ['V']
# StzdmmnnjS
# RRdhPPdZZd
# ['d']
# ['d']
# VbTbCqFFMbZTF
# cNQLgRgQbvvRh
# ['b', 'b', 'b']
# ['b']
# pGsqGGGfHGfZVff
# zwtrHnmJHllznrS
# ['H']
# ['H']
# NLWJvtLjtLzBjNSvS
# MDCHfwHSlDMlSSHfZ
# ['S', 'S']
# ['S']
# RTPTVmhpnp
# rfcfgZwgRD
# ['R']
# ['R']
# PnPGFhGsTphsFpdPnpVdmhwF
# vBJzbdWNtJJjtNJNjbvJtttN
# ['d', 'd']
# ['d']
# RvmgjDqqjqRgZRMRDpQjQhW
# sbPLPFnPFFbVVLbdSbnPSvP
# ['v']
# ['v']
# NwczHBrJTzcBJHrfWJBCJcrC
# dnPPPNSlLnsnbFnnLlbSFddS
# ['N']
# ['N']
# rGJwCCCJHwBGGctG
# DtphQQMppQWZmRpD
# ['t']
# ['t']
# RPhhSMqRccBDZPPPRhPcNZS
# zzTLJrWZLmVVQLWZdTQQJWL
# ['Z', 'Z']
# ['Z']
# nwggfwCvbjwvbwp
# zWLpWVLdrrrQVTm
# ['p']
# ['p']
# vgnGGCsCtntbFsg
# qlRVMSqNVBDtPSc
# ['t', 't']
# ['t']
# mtstjJmvTN
# BcjRRCHCfH
# ['j']
# ['j']
# gLpglwwlgHbZbgpgF
# rdBBBfdfSPBLSSrcS
# ['L']
# ['L']
# GQGglGWWgMglQFHgb
# mTmNtDqnDDVJMDMNJ
# ['M']
# ['M']
# ZMbBZfvVfFfBbMvfMhgbf
# DsrSTTszcldmTTPmcPFDz
# ['F']
# ['F']
# QqQQnwrqWQpwRWWpWwJRwN
# zTTSPpzPPdTPpSPmdSscmS
# ['p', 'p']
# ['p']
# GjjtJRWtwGQjR
# ZVChZMjVCrMMf
# ['j', 'j', 'j']
# ['j']
# fJNPTvDPTpHHTPwvjNNHDfT
# WthhgQQGdBddtlvMsMQMvQh
# ['v', 'v']
# ['v']
# rFbZVZrLmL
# dGrrhMBQWg
# ['r', 'r']
# ['r']
# FmnzVRFLqVqqVLVRRFZSFm
# TwfHHjHCNCCDGwjnCDDfNH
# ['n']
# ['n']
# gQHHQJgCnNJn
# QFQPRbDQzLRR
# ['Q', 'Q']
# ['Q']
# mwrdpctWtrMvvrrWwGMmGWW
# PLzFFLSbLnDFsLPdDFbZRLz
# ['d']
# ['d']
# vGcmGwBBMGtmmrvlMrGl
# qNghlVjCCnTHHCHgCCjh
# ['l', 'l']
# ['l']
# LmLvVjVj
# srmrtmmr
# ['m']
# ['m']
# tfcnbScRnlMZt
# HQPCgSQssPdHC
# ['S']
# ['S']
# RGGGGnRfcwnGbbJRBRcwJfnG
# tBDhhVptNhDvLLhVvvjBWNvT
# ['B']
# ['B']
# dZWNQZgQbbNvdWGgZvb
# TfLrjtrPlGJfrLqLJlj
# ['G']
# ['G']
# TMmDpwzmVMHpB
# LfrcccMfqLjct
# ['M', 'M']
# ['M']
# SwnSBTDDTwwzwnnsF
# SZdRNbQZWRvgSCvbQ
# ['S', 'S']
# ['S']
# WPgZgQLLbMgdB
# rdnGqqfdhVVvR
# ['d']
# ['d']
# HzssNTzwlwHHcczwFjMFHj
# VGrqRqnVThVqrGrGTRqvrf
# ['T']
# ['T']
# zFzcHFNlzJ
# BLgMQLJCZL
# ['J']
# ['J']
# nPLNcWtNtlLMccLlWd
# TjzzbBfBQSzqzBqPqS
# ['P']
# ['P']
# RbbDZZrGRJhJ
# jgJQSjCfqQCC
# ['J', 'J']
# ['J']
# rrmRbDDwvZDpprbGrbDv
# tctlVVVHvdtlcMtWHMHV
# ['v', 'v']
# ['v']
# DWrZJrQjWwFcr
# hzVzbpmpcVqhb
# ['c']
# ['c']
# MFnFHMNS
# qbMpMMmG
# ['M', 'M']
# ['M']
# FNngNRBRCgnHCCHRPvLNdg
# JWwJDlJJDssZDLWWlWQlsl
# ['L']
# ['L']
# BQqNsGrbBCNbNCrMpGpb
# HhthRCDRDRJCmDVRhRJP
# ['C', 'C']
# ['C']
# nfvWvcnSWncSTdzzFLJ
# tRmhHmPPVPVTwwHHtTh
# ['T']
# ['T']
# WfLfnfSJZJvdLFZWngf
# BMGMppGMrNBbGMpZjrj
# ['Z', 'Z']
# ['Z']
# rccMjBMVJc
# jjjNNqmmCf
# ['j']
# ['j']
# LLspTTGsTGntsntTFwn
# NNfFqQmmNgNqfNQmZvQ
# ['F']
# ['F']
# tpDTwlGDTGPPsbtsLsnnqGT
# JzJrJBzHzMVrMRzBMlShVBR
# ['l']
# ['l']
# PsrNPRjjPbjzjLRWLbj
# mvtCnMntnpfmtNZNCNv
# ['N']
# ['N']
# dDlfwwJllhJTcllSc
# SCQvmtCnmtCmQmQmG
# ['S']
# ['S']
# TTFcdhJwhBFfwJJHhdchVcl
# rsbWsbzqLgbzrrjgVRgsqgW
# ['V']
# ['V']
# vvcvvDJFcDZPT
# zwfcwSLczzScz
# ['c', 'c']
# ['c']
# VNnnVVsqGNntsqtBRblqBn
# dSfzCCRzwRfCHSjdfSjzSH
# ['R']
# ['R']
# pppsMVlGG
# hhrZwMMDP
# ['M']
# ['M']
# LltNHMZNHMfNnfgtLH
# WWbhWjcblSbVbcTWVP
# ['l']
# ['l']
# vFmCZsqRRBq
# rVPWsWTWPWb
# ['s']
# ['s']
# mQBqJRdqQBqQzzRQz
# tgLgntGZttddLMggw
# ['d']
# ['d']
# ZTCCrCWfGLGBW
# SwHvHHmHvmTTH
# ['T']
# ['T']
# bllhnsbjDlqFfqjhnFR
# ppwmvJppmpRRwMNSmmw
# ['R']
# ['R']
# FlnFDjdtqhDd
# fZZBrtBrrPLt
# ['t']
# ['t']
# CRCTHHJcCmJgTSTRcSMcRM
# VstssSrtprppVFtdrdspNb
# ['S', 'S']
# ['S']
# jjllnvgBLq
# dsGprtqtFG
# ['q']
# ['q']
# vQjzWnWZWjBLhj
# gwcccRJgZPCmJm
# ['Z']
# ['Z']
# VRNmBBRNRFcCRcFVRSVS
# qZLLvvlLqvLfzfMhjJLC
# ['C']
# ['C']
# TdHsHbDsb
# HMJLqlLzl
# ['H', 'H']
# ['H']
# bgQGsgWWGGgbDgwGz
# BNSFrFtVSmwRRNFtn
# ['w']
# ['w']
# pCCggQPPzWnv
# lDcWVHGJcNBl
# ['W']
# ['W']
# LhsLMrww
# GlnMBlNG
# ['M']
# ['M']
# mmhwZmqSLwjLttn
# FbvgFTpPtPtgFCz
# ['t', 't']
# ['t']
# TtZSJzFZhZzTFcgFFcmRRmJJ
# QllCHvPshVQsCrshsCssHVHW
# ['h']
# ['h']
# GjGGDGqdGfbpDBjMdjpBjBNb
# VHtsWWPHlMlrrrrWWlVlVsCs
# ['M']
# ['M']
# dBdDdfqLdBjj
# FRFScRStmLnL
# ['L']
# ['L']
# GtVppGGPbVgTVF
# QrZzfrJfJJtMJr
# ['t']
# ['t']
# DslmNmLsnmNHNNnn
# qQRZSJSQfqrJzSJn
# ['n', 'n', 'n']
# ['n']
# BNljDHsHlvhmBshDljWsDWlH
# dgvpVTFggVgGcTTpvFPTzGCV
# ['v']
# ['v']
# GRcnTRtcQTcBTsN
# tpvhFCmmFhZvFPC
# ['t']
# ['t']
# bBJMgqWfdwBJfM
# PPPmvPqhmjvvPC
# ['q']
# ['q']
# SMJMdJbdfwJgVglMWWVd
# cQnBzSQDzGGQzRQDTQSB
# ['S']
# ['S']
# mvjVzLgTzVzvVjJrJgr
# lMhZRFTtRlRhMRRRtFZ
# ['T']
# ['T']
# HGqnNNqfnHNGGfCHndBqnqf
# FlcppsJMZplMFpMtlscRlpC
# ['C']
# ['C']
# qSnPGqqbnSd
# VrvQrrSJjSV
# ['S', 'S']
# ['S']
# lWFSWZZvVqnqfnSr
# JzMcPDjJBJcBMPFJ
# ['F']
# ['F']
# NGppNgHdHbRsHPbsgGspTwHT
# McmMDdJMMmzBDcMBMDQmjMBd
# ['d']
# ['d']
# TGGLRGwHsGtpHgHpNbpttw
# rvCnvCrqSSLvWqPqSSnWvn
# ['L']
# ['L']
# jwcqBNNdZLj
# SfvPdddRlfb
# ['d']
# ['d']
# CDVmsgMHCnnDnhVghmDnDC
# zRRrSrbrlTbsSTlzzlvzPb
# ['s']
# ['s']
# gCCFmCWDnChGCFHnGC
# LBcwwjvZQZNtGqqNZc
# ['G', 'G']
# ['G']
# LBDcNstdNJscccVDhLHNDHVt
# FvdldlFvCSnSvjSSbblgvZjF
# ['d']
# ['d']
# rWznQqGMMrmmR
# ZbbwvSFgjwbwm
# ['m', 'm']
# ['m']
# RQnTQfWqqTz
# TLJJLVtBTsc
# ['T', 'T']
# ['T']
# SvwCTHqCqqqHtwtnnHHDtW
# grBQLzzVLLzSQVFhbrSFLL
# ['S']
# ['S']
# cZmPNmPJdmPjPdcclRPPd
# hBCFVVVrQzQCCLbcgVbBV
# ['c', 'c', 'c']
# ['c']
# fNlmfZfpf
# WMCtGGpnM
# ['p']
# ['p']
# bSNssNssbPH
# VccPhclPGpP
# ['P']
# ['P']
# ffQfZdZZBDDZgLv
# hmhzVmVppmlpGgh
# ['g']
# ['g']
# jdQQQJRl
# jSFFTWCT
# ['j']
# ['j']
# lvlLtvnhnfvMgtrvW
# jmTmPPzjHcrmdcjdd
# ['r']
# ['r']
# qCbssCJbppQZQbRJDQSZCJRp
# zhmcQjdcTBmmGzmdcmjGmdmT
# ['Q', 'Q', 'Q']
# ['Q']
# SqwSbJZSpwwFJFDDbq
# tNVMwVMMlVNgNVlLhV
# ['w', 'w', 'w']
# ['w']
# DqGFQGNMGM
# QwCcgtCJcr
# ['Q']
# ['Q']
# sVfjWlzzVsmzVZsdVl
# HrhjppcgpjrhpphcSJ
# ['j']
# ['j']
# LRdLsZBWWmlZldZRmz
# PDvDTTDMGTPFPvBTTc
# ['B']
# ['B']
# jzzzpjgB
# zTDQQHPH
# ['z', 'z', 'z']
# ['z']
# gLLtZVdCdsLfnbZCbdZt
# HDfHTJJPPmJJfmHQDJqD
# ['f']
# ['f']
# bVtWndLtcZgnhs
# vMSBrMFrvBWNrB
# ['W']
# ['W']
# sfqhLDcqfqRRqQhQRqMcv
# lJpJwFgzwpjplwbgpwzLz
# ['L']
# ['L']
# CrGttnhTWtmSnGrtTtSCZG
# FzbgHHFFFjljHjZHHFwgwl
# ['Z']
# ['Z']
# mBnrrTmWWCGStVCm
# McDPcPBqcsRhcvPR
# ['B']
# ['B']
# GLZLBNrGZdG
# GVgMVJVhnvn
# ['G', 'G', 'G']
# ['G']
# dmWlcqcQ
# MWCJVhMn
# ['W']
# ['W']
# cdpPqtQbcHlmQjm
# ZswFfTRFpBTfwwT
# ['p']
# ['p']
# ZhtZpvbnbpPbt
# LHLvdsNdcRLNd
# ['v']
# ['v']
# jDDjlCflGws
# HfdrfTLrrdN
# ['f']
# ['f']
# MzmljBMBW
# PtsbtSQtW
# ['W']
# ['W']
# GHrzPSrNLF
# nMtSBZjZBB
# ['S']
# ['S']
# WWbfDmVmwmmlbVDldW
# slNnBMJJNZZJCtJJJn
# ['l', 'l']
# ['l']
# vwDfffVvmDwdTvDRQv
# pLNpLpcRFpphhHLPHg
# ['R']
# ['R']
# scsTslgcnCTCScSTc
# qLLWlFWLLqbGvRbpL
# ['l']
# ['l']
# NZMBdBPtNbb
# rLGqqqGvqZF
# ['Z']
# ['Z']
# NttdbhMPfjQfNtbMbMmNjhN
# cCzczSSCSJTSzTCScnfnzwC
# ['f', 'f']
# ['f']
# pjdjCGGG
# WPCMSDfS
# ['C']
# ['C']
# JhFMFcrgBH
# PnSnWFWDDn
# ['F', 'F']
# ['F']
# HVBBJctBccghsJhgr
# bwLGTTdtjLdbmTMMb
# ['t']
# ['t']
# DtGHgDPfGfPhf
# LwNWSSJQcpHcr
# ['H']
# ['H']
# dvlMCzdnMRFCCTjnZ
# NpNQJcSbrWzrpSQWS
# ['z']
# ['z']
# TVvFJJMjJdlMvRvMClllZZ
# gPtPGsftfDqtGfVGsGtqqq
# ['V']
# ['V']
# jSmmcjmJqcBg
# wmWMCLLzCsMz
# ['m', 'm', 'm']
# ['m']
# TnTQVDGQTpZGNQHDZDHHQD
# wsCCdLrflsrCVzVrwWzwrr
# ['V']
# ['V']
# zDFpppnNQtnTQQvZZZNvn
# hqqjtRccRbgqqbSSSjPRg
# ['t']
# ['t']
# FwClNSwCFstWZ
# LDLvhvjvtjhhD
# ['t']
# ['t']
# TmsHmsmrggzmqnn
# GGvPGjTbbRGBhbB
# ['T']
# ['T']
# cHVqgcrVzrQqzHmMcrMnczzc
# WFVCCFNJZWJZswwFCZWwffwS
# ['V', 'V']
# ['V']
# mzbsmbmLRCZTRbS
# JFvPLPJPJpJffcP
# ['L']
# ['L']
# QqWqNVNNNllnnWTglqTVlGN
# PJDvwcJpwfwccPgccPJDfJF
# ['g']
# ['g']
# HMGnNMltqGMjHGq
# MzmTSmzTsRSszSm
# ['M', 'M', 'M']
# ['M']
# qlGDfljllCTgqCTvCDf
# BHHQsbrSZZHSHWtvWZB
# ['v']
# ['v']
# NzpnNpRnLLwRpdwpVh
# tqQbSbsWQWbSWnrrnH
# ['n', 'n']
# ['n']
# cFqwFNpLdV
# cDJlDgccTD
# ['c']
# ['c']
# BRqjnSBNBpRHHpjpBSnHnRBQ
# fQzzCvzWrsWCTvfsvCsCCsfC
# ['Q']
# ['Q']
# ZMVbhqbMdlb
# LTdsWvfPdPC
# ['d']
# ['d']
# hlZVDMZcwJ
# NSgjJgJFnq
# ['J']
# ['J']
# CZwZssQQZrmsC
# mNNDpDGFblclD
# ['m']
# ['m']
# HMjWMbBVfnnbMbnzM
# pFhlNSNFFSDcDGSzN
# ['z']
# ['z']
# LnLLqjnBMjMngHbnW
# rTgZsCsgZvvvQrvQs
# ['g']
# ['g']
# RCFCCJQbCQc
# prRlHHPpHhd
# ['R']
# ['R']
# tWWLwvswfvZs
# hgqDpdpBgfdf
# ['f']
# ['f']
# mZtvZtMpjZzwW
# FjJTcQQbjjnSQ
# ['j']
# ['j']
# fBfVwtttLDFctDtwFP
# WfTppWfmHCHdJhdChT
# ['f', 'f']
# ['f']
# bGMRsbsvMQSSzMzZSNzsZvRN
# WTZJlmgZTJJdhhmppHTJCgTg
# ['Z', 'Z']
# ['Z']
# jssjNSSGMsQHbsRvHN
# PjtDcDcLPPPPDwLDDV
# ['j', 'j']
# ['j']
# pClhQjJccrpbp
# qHhMhVhSMqHPt
# ['h']
# ['h']
# dBZGZdgBzRsBsv
# MwGGVPVqMGwtVH
# ['G']
# ['G']
# ZvDddZvDBdDdDmg
# CmVmbbCNpCCbljW
# ['m']
# ['m']
# DTMCpdCnwRDwdfMCDDCssf
# ZmGrBrjpttjrNrgctmGpGr
# ['p']
# ['p']
# VVqJQgSSWzh
# PGGrPtNNQtm
# ['Q']
# ['Q']
# bFvhgWzHJl
# DdffswTvRd
# ['v']
# ['v']
# jwCCPPTtCswCCNTsqRN
# bMqQMVvVzMMMQSGvQqn
# ['q']
# ['q']
# hprHlmFcHcdhWWLchZzHrL
# MvvnBvJJSBJMVMnnmMnMMJ
# ['m']
# ['m']
# WppLcZdHWHplZWlDHhH
# TfzRzCCsTTtNNgtjgDw
# ['D']
# ['D']
# vhmDFcDZmczMrwcqrMrmDFrv
# ggtVSWgtSNwsjBtNVSnBsjsS
# ['w']
# ['w']
# dbbRJHbpC
# WBBpZVgSS
# ['p']
# ['p']
# LZLdHlClP
# mqLGDvMDv
# ['L', 'L']
# ['L']
# mFbWsvsJV
# tbbRwfTSP
# ['b']
# ['b']
# BGpQllhLGqhplBGZB
# fLMTSTLwwfwMJwMPT
# ['L']
# ['L']
# GlDnDpQZlZZpZBlp
# WDNcmrgrWmNdNJvc
# ['D', 'D']
# ['D']
# zbtqTtHQbZZpqbPp
# vGJdvQdhrhQjdQGs
# ['Q']
# ['Q']
# qDFLLSNqc
# WwsGhGDJh
# ['D']
# ['D']
# LgBcfnFCSFnLccggSVCV
# tHZlpqPPtTRMftHMbMzb
# ['f']
# ['f']
# hzrrWnzRZRnbWVRzjcR
# HMDdqqQdNMHqHQQjlHM
# ['j']
# ['j']
# sGCpCtppBfCTgwBBCwPBCss
# QqMQvNlSMMQDQNqHGHvDSbQ
# ['G']
# ['G']
# tpLFPgfbCsfb
# zzcnJhRhZLhc
# ['L']
# ['L']
# qzzGqfpFvW
# FmRSPjPjRP
# ['F']
# ['F']
# cwwVssBMtNMNLngstgVBnrs
# PmHSJJmjllhQdQldmhdrjQJ
# ['r']
# ['r']
# nDVSsLwcVcMnB
# GzTDDCvpvfzGT
# ['D']
# ['D']
# bcTbbcZGZLPgTMWZpLL
# DQnrvPVnVmmjmRPFVrF
# ['P']
# ['P']
# HJCJqlzBdsSjzCJ
# RmlrlrnVQQDFnVF
# ['l']
# ['l']
# BfwffNdNsw
# LtbWbNcpjt
# ['N', 'N']
# ['N']
# smJwSNNFMzFN
# DrvbrbfJHvbl
# ['J']
# ['J']
# BRQjqZQcBh
# rbTsbTnfcn
# ['c']
# ['c']
# ZLQRZRBjjPW
# SsmCdSWMgSN
# ['W']
# ['W']
# NhwlDpbWgg
# dSBvBggLFg
# ['g', 'g']
# ['g']
# fRrZsVfjqljmsQQVmms
# nFMFSBLLRvFTFMBSvFF
# ['R']
# ['R']
# QfqVVzcsQmcQqrcs
# NwzzzPphHlwNppPH
# ['z']
# ['z']
# nnFdsjVdmpBsBVFHzjp
# vlTfQdPcQQPGPcvlGPv
# ['d', 'd']
# ['d']
# DWMDCCWbNJhLtMgJMNLgtMg
# QflZQlfQGjZZhQZGhTfQcQP
# ['h']
# ['h']
# rCrtJJgLLMbgDgMDWNRrW
# RnzsjpFzBzSHmmqHmqnHH
# ['R']
# ['R']
# rmjjJmmdwSmGhdsjJtsgG
# NzFWQFnBFVWHdFQcLLcNz
# ['d', 'd']
# ['d']
# RCCbfRlvvPfvCT
# nHLLnNbNLczHnQ
# ['b']
# ['b']
# lqZTllRRpDMlpfZRv
# gQpSmwwtggQjJgtpS
# ['p', 'p']
# ['p']
# LDsGvTSSsswCwTrLZD
# qQWHMWbphlHMpGGpQz
# ['G']
# ['G']
# RRPfPRccBdVjPc
# FlpMpMQWzMWfpF
# ['f']
# ['f']
# RjPRjRtczcNBJR
# SCtLDTvTSDCCST
# ['t']
# ['t']
# pqQNgNnSntwgqzzQCzNwCN
# BRcWtBjZcZGrBMcHMGvWcr
# ['t']
# ['t']
# mmJdJPFVbJbPP
# GZbMRbvvrjcMj
# ['b', 'b']
# ['b']
# lTMVVlLPfL
# NQhpgqLSLn
# ['L', 'L']
# ['L']
# HlBHFrgBvlfzFzqvnvFq
# pCJbJfQpQpLcmhbcmtmm
# ['f']
# ['f']
# jDjPGsRRTMMP
# jdJmjmLpCLth
# ['j', 'j']
# ['j']
# MRMZMWsN
# pFFFVFHW
# ['W']
# ['W']
# RGgwWcppGSWcWSRWmGdWc
# ttHQFJHfbQwBQJTJQBQfJ
# ['w']
# ['w']
# njjZZCMlCZjqM
# BFbJQZHJHBQft
# ['Z', 'Z', 'Z']
# ['Z']
# DsjCPDDvjFNsMNjNq
# pGspcsGSmcpccrGWS
# ['s', 's']
# ['s']
# cVwMZGVZwHNPgPwRZwH
# ttThlHllvlzQpptzppl
# ['H', 'H']
# ['H']
# DsCWdqLdDCnfJLSCqsqWRsBd
# lhjlhzlttzQhhtvlhnhhhbzT
# ['n']
# ['n']
# JCWWRWCrLDDdBdLsSsLLSCrC
# NZMVcmMZMFwMZwNZPZVGFPmr
# ['r', 'r']
# ['r']
# hhPzDzPhPNbfpzhBbdNbDh
# ttzqWtwttHWwntjqmwmWFm
# ['z', 'z', 'z']
# ['z']
# LgGZSdMMrgTLrZLdgLSgsGT
# FFjrWtFFmmmFtWjqHFnFtjn
# ['r', 'r']
# ['r']
# vZgdLvZLZQLRQZQQdMZLdQv
# VpRhNNPfJDbcBbbhVNJNNhf
# ['R']
# ['R']
# [array(['W'], dtype='<U1'), array(['V'], dtype='<U1'), array(['Z'], dtype='<U1'), array(['C'], dtype='<U1'), array(['V'], dtype='<U1'), array(['c'], dtype='<U1'), array(['W'], dtype='<U1'), array(['S'], dtype='<U1'), array(['z'], dtype='<U1'), array(['c'], dtype='<U1'), array(['q'], dtype='<U1'), array(['t'], dtype='<U1'), array(['L'], dtype='<U1'), array(['H'], dtype='<U1'), array(['N'], dtype='<U1'), array(['S'], dtype='<U1'), array(['R'], dtype='<U1'), array(['J'], dtype='<U1'), array(['L'], dtype='<U1'), array(['m'], dtype='<U1'), array(['q'], dtype='<U1'), array(['w'], dtype='<U1'), array(['Q'], dtype='<U1'), array(['l'], dtype='<U1'), array(['m'], dtype='<U1'), array(['V'], dtype='<U1'), array(['f'], dtype='<U1'), array(['T'], dtype='<U1'), array(['Q'], dtype='<U1'), array(['r'], dtype='<U1'), array(['f'], dtype='<U1'), array(['j'], dtype='<U1'), array(['Z'], dtype='<U1'), array(['h'], dtype='<U1'), array(['f'], dtype='<U1'), array(['v'], dtype='<U1'), array(['T'], dtype='<U1'), array(['C'], dtype='<U1'), array(['g'], dtype='<U1'), array(['D'], dtype='<U1'), array(['S'], dtype='<U1'), array(['w'], dtype='<U1'), array(['s'], dtype='<U1'), array(['v'], dtype='<U1'), array(['R'], dtype='<U1'), array(['B'], dtype='<U1'), array(['v'], dtype='<U1'), array(['N'], dtype='<U1'), array(['M'], dtype='<U1'), array(['p'], dtype='<U1'), array(['m'], dtype='<U1'), array(['z'], dtype='<U1'), array(['C'], dtype='<U1'), array(['Q'], dtype='<U1'), array(['L'], dtype='<U1'), array(['S'], dtype='<U1'), array(['d'], dtype='<U1'), array(['t'], dtype='<U1'), array(['h'], dtype='<U1'), array(['G'], dtype='<U1'), array(['b'], dtype='<U1'), array(['j'], dtype='<U1'), array(['w'], dtype='<U1'), array(['D'], dtype='<U1'), array(['p'], dtype='<U1'), array(['C'], dtype='<U1'), array(['T'], dtype='<U1'), array(['n'], dtype='<U1'), array(['J'], dtype='<U1'), array(['S'], dtype='<U1'), array(['c'], dtype='<U1'), array(['M'], dtype='<U1'), array(['P'], dtype='<U1'), array(['M'], dtype='<U1'), array(['d'], dtype='<U1'), array(['s'], dtype='<U1'), array(['v'], dtype='<U1'), array(['L'], dtype='<U1'), array(['h'], dtype='<U1'), array(['w'], dtype='<U1'), array(['c'], dtype='<U1'), array(['g'], dtype='<U1'), array(['W'], dtype='<U1'), array(['T'], dtype='<U1'), array(['N'], dtype='<U1'), array(['D'], dtype='<U1'), array(['v'], dtype='<U1'), array(['c'], dtype='<U1'), array(['F'], dtype='<U1'), array(['N'], dtype='<U1'), array(['w'], dtype='<U1'), array(['R'], dtype='<U1'), array(['t'], dtype='<U1'), array(['C'], dtype='<U1'), array(['Q'], dtype='<U1'), array(['V'], dtype='<U1'), array(['d'], dtype='<U1'), array(['b'], dtype='<U1'), array(['H'], dtype='<U1'), array(['S'], dtype='<U1'), array(['R'], dtype='<U1'), array(['d'], dtype='<U1'), array(['v'], dtype='<U1'), array(['N'], dtype='<U1'), array(['t'], dtype='<U1'), array(['Z'], dtype='<U1'), array(['p'], dtype='<U1'), array(['t'], dtype='<U1'), array(['j'], dtype='<U1'), array(['L'], dtype='<U1'), array(['M'], dtype='<U1'), array(['F'], dtype='<U1'), array(['p'], dtype='<U1'), array(['j'], dtype='<U1'), array(['v'], dtype='<U1'), array(['r'], dtype='<U1'), array(['n'], dtype='<U1'), array(['Q'], dtype='<U1'), array(['d'], dtype='<U1'), array(['l'], dtype='<U1'), array(['m'], dtype='<U1'), array(['S'], dtype='<U1'), array(['B'], dtype='<U1'), array(['G'], dtype='<U1'), array(['M'], dtype='<U1'), array(['S'], dtype='<U1'), array(['d'], dtype='<U1'), array(['T'], dtype='<U1'), array(['J'], dtype='<U1'), array(['P'], dtype='<U1'), array(['J'], dtype='<U1'), array(['v'], dtype='<U1'), array(['c'], dtype='<U1'), array(['M'], dtype='<U1'), array(['L'], dtype='<U1'), array(['C'], dtype='<U1'), array(['T'], dtype='<U1'), array(['Z'], dtype='<U1'), array(['j'], dtype='<U1'), array(['F'], dtype='<U1'), array(['l'], dtype='<U1'), array(['N'], dtype='<U1'), array(['S'], dtype='<U1'), array(['V'], dtype='<U1'), array(['c'], dtype='<U1'), array(['R'], dtype='<U1'), array(['M'], dtype='<U1'), array(['l'], dtype='<U1'), arr ...

# %% [markdown]
# --- Part Two ---
#
# As you finish identifying the misplaced items, the Elves come to you with another issue.
#
# For safety, the Elves are divided into groups of three. Every Elf carries a badge that identifies their group. For efficiency, within each group of three Elves, the badge is the only item type carried by all three Elves. That is, if a group's badge is item type B, then all three Elves will have item type B somewhere in their rucksack, and at most two of the Elves will be carrying any other item type.
#
# The problem is that someone forgot to put this year's updated authenticity sticker on the badges. All of the badges need to be pulled out of the rucksacks so the new authenticity stickers can be attached.
#
# Additionally, nobody wrote down which item type corresponds to each group's badges. The only way to tell which item type is the right one is by finding the one item type that is common between all three Elves in each group.
#
# Every set of three lines in your list corresponds to a single group, but each group can have a different badge item type. So, in the above example, the first group's rucksacks are the first three lines:
#
# vJrwpWtwJgWrhcsFMMfFFhFp
# jqHRNqRjqzjGDLGLrsFMfFZSrLrFZsSL
# PmmdzqPrVvPwwTWBwg
# And the second group's rucksacks are the next three lines:
#
# wMqvLMZHhHMvwLHjbvcjnnSBnvTQFn
# ttgJtRGJQctTZtZT
# CrZsJsPPZsGzwwsLwLmpwMDw
# In the first group, the only item type that appears in all three rucksacks is lowercase r; this must be their badges. In the second group, their badge item type must be Z.
#
# Priorities for these items must still be found to organize the sticker attachment efforts: here, they are 18 (r) for the first group and 52 (Z) for the second group. The sum of these is 70.
#
# Find the item type that corresponds to the badges of each three-Elf group. What is the sum of the priorities of those item types?
